# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, VotingRegressor
from sklearn.metrics import r2_score

# %%
data=pd.read_csv('/Users/omgajipara/Desktop/Data Science/AI:ML/Machine Learning/Supervised Learning/Regression/Simple_Linear_Regression/SimpleLinearRegression.csv')
data
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
sns.scatterplot(x="cgpa", y="package", data=data, hue="package")
plt.title("Scatter plot of x1 vs x2 colored by y")
plt.show()

# %%
r1 = RandomForestRegressor(n_estimators=100, random_state=42)
r2 = GradientBoostingRegressor(n_estimators=100, random_state=42)
r3 = AdaBoostRegressor(n_estimators=100, random_state=42)

# %%
ensemble_model = VotingRegressor(estimators=[
    ('rf', r1),
    ('gb', r2),
    ('ada', r3)
])

# %%
ensemble_model.fit(x_train, y_train)

# %%
y_pred = ensemble_model.predict(x_test)

r2 = r2_score(y_test, y_pred)

print(f"🧠 R² Score (Ensemble): {r2:.4f}")
print(f"✅ Training Score: {ensemble_model.score(x_train, y_train) * 100:.2f}%")
print(f"🧪 Testing Score: {ensemble_model.score(x_test, y_test) * 100:.2f}%")
# Out:
# ✅ Training Accuracy: 95.16%
# 🧪 Testing Accuracy: 52.20%

# %%
from sklearn.svm import SVR

dt = SVR()
dt.fit(x_train, y_train)

train_accuracy = dt.score(x_train, y_train) * 100
test_accuracy = dt.score(x_test, y_test) * 100

print(f"✅ Training Accuracy: {train_accuracy:.2f}%")
print(f"🧪 Testing Accuracy: {test_accuracy:.2f}%")
# Out:
# ✅ Training Accuracy: 78.17%
# 🧪 Testing Accuracy: 75.95%

# %%
from sklearn.naive_bayes import GaussianNB

dt = GaussianNB()
dt.fit(x_train, y_train)

train_accuracy = dt.score(x_train, y_train) * 100
test_accuracy = dt.score(x_test, y_test) * 100

print(f"✅ Training Accuracy: {train_accuracy:.2f}%")
print(f"🧪 Testing Accuracy: {test_accuracy:.2f}%")

# %%
from sklearn.ensemble import VotingClassifier

# %%
li = [("dt1", DecisionTreeRegressor()), 
      ("SVR", SVR()), 
      ("gaussian", GaussianNB())]

# %%
vt=VotingClassifier(li)
vt.fit(x_train,y_train)

# %%
vt.score(x_train,y_train)*100,vt.score(x_test,y_test)*100
